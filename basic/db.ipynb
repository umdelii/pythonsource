# %% [markdown]
# ### DB 연동
# - 내장 DB 제공 : sqlite(RDBMS)
# - 외부 DB 사용 가능 : mysql, mongo db
# - 라이브러리 설치 : pymysql

# %% [markdown]
# #### 연결
# - connect() : db 서버 연동
# - cursor : db 연결 후 접근할 수 있는 객체

# %%
import pymysql

# %%
conn = pymysql.connect(
    host="localhost",
    user="java_db",
    password="12345",
    database="springdb",
    charset="utf8mb4",
)

# %% [markdown]
# #

# %% [markdown]
# #### 조회
# - fetchall()
# - fetchone()
# - fetchmany()

# %%
with conn.cursor() as cursor:
    sql = "select * from book"
    cursor.execute(sql)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (2, '정이안', 'The Chase', 'B10011', 45000, 'book1')
# (3, '정이안', 'Focus', 'B10001', 70770, 'book1')
# (4, '정이안', None, 'B10002', 80000, 'book2')
# (5, '정이안', None, 'B10003', 80000, 'book3')
# (6, '정이안', None, 'B10004', 80000, 'book4')
# (7, '정이안', None, 'B10005', 80000, 'book5')
# (8, '정이안', None, 'B10006', 80000, 'book6')
# (9, '정이안', None, 'B10007', 80000, 'book7')
# (11, '정이안', None, 'B10009', 80000, 'book9')
# (12, '정이안', None, 'B100010', 80000, 'book10')
# (13, '정이안', 'The Chase', '3abbebb4-d58e-11f0-9b7b-c85acfa7cde3', 38000, 'book1')
# (14, '정이안', 'Focus', '3abbedc4-d58e-11f0-9b7b-c85acfa7cde3', 70770, 'book1')
# (15, '정이안', None, '3abbee57-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book2')
# (16, '정이안', None, '3abbee9f-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book3')
# (17, '정이안', None, '3abbeeb7-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book4')
# (18, '정이안', None, '3abbeecc-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book5')
# (19, '정이안', None, '3abbeedf-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book6')
# (20, '정이안', None, '3abbeef1-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book7')
# (21, '정이안', None, '3abbef03-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book8')
# (22, '정이안', None, '3abbef17-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book9')
# (23, '정이안', None, '3abbef2b-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book10')
# (28, '정이안', 'The Chase', '8146dae7-d58e-11f0-9b7b-c85acfa7cde3', 38000, 'book1')
# (29, '정이안', 'Focus', '8146db9b-d58e-11f0-9b7b-c85acfa7cde3', 70770, 'book1')
# (30, '정이안', None, '8146dbba-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book2')
# (31, '정이안', None, '8146dbdc-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book3')
# (32, '정이안', None, '8146dbf2-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book4')
# (33, '정이안', None, '8146dc0c-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book5')
# (34, '정이안', None, '8146dc22-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book6')
# (35, '정이안', None, '8146dc36-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book7')
# (36, '정이안', None, '8146dc4a-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book8')
# (37, '정이안', None, '8146dc60-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book9')
# (38, '정이안', None, '8146dc74-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book10')
# (39, '정이안', 'The Chase', '8146dc8d-d58e-11f0-9b7b-c85acfa7cde3', 38000, 'book1')
# (40, '정이안', 'Focus', '8146dca3-d58e-11f0-9b7b-c85acfa7cde3', 70770, 'book1')
# (41, '정이안', None, '8146dcb6-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book2')
# (42, '정이안', None, '8146dcca-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book3')
# (43, '정이안', None, '8146dcde-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book4')
# (44, '정이안', None, '8146dcef-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book5')
# (45, '정이안', None, '8146dd00-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book6')
# (46, '정이안', None, '8146dd11-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book7')
# (47, '정이안', None, '8146dd25-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book8')
# (48, '정이안', None, '8146dd39-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book9')
# (49, '정이안', None, '8146dd4c-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book10')
# (59, '정이안', 'The Chase', '822737bf-d58e-11f0-9b7b-c85acfa7cde3', 38000, 'book1')
# (60, '정이안', 'Focus', '822738f0-d58e-11f0-9b7b-c85acfa7cde3', 70770, 'book1')
# (61, '정이안', None, '82273924-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book2')
# (62, '정이안', None, '8227394c-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book3')
# (63, '정이안', None, '82273971-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book4')
# (64, '정이안', None, '82273991-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book5')
# (65, '정이안', None, '822739b2-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book6')
# (66, '정이안', None, '822739d3-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book7')
# (67, '정이안', None, '822739f2-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book8')
# (68, '정이안', None, '82273a19-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book9')
# (69, '정이안', None, '82273a3b-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book10')
# (70, '정이안', 'The Chase', '82273a64-d58e-11f0-9b7b-c85acfa7cde3', 38000, 'book1')
# (71, '정이안', 'Focus', '82273a85-d58e-11f0-9b7b-c85acfa7cde3', 70770, 'book1')
# (72, '정이안', None, '82273aab-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book2')
# (73, '정이안', None, '82273ad0-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book3')
#
d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book8')
# (424, '정이안', None, 'd72cdce8-d58e-11f0-9b7b-c85acfa7cde3', 80000, 'book10')
# (506, 'awef', 'awefawef', 'B10044', 112415, 'eeee')

# %%
with conn.cursor() as cursor:
    sql = "select * from book"
    cursor.execute(sql)
    row = cursor.fetchone()
    print(row)
# Out:
# (2, '정이안', 'The Chase', 'B10011', 45000, 'book1')

# %% [markdown]
# ## 테이블 생성

# %%
with conn.cursor() as cursor:
    sql = "create table if not exists users" \
        "(id int primary key auto_increment, name varchar(30), email varchar(100), phone varchar(20), website varchar(50), regdate date)"
    cursor.execute(sql)

# %% [markdown]
# ### insert

# %%
# import datetime
# datetime.datetime.now()

from datetime import datetime

print(datetime.now())
now1 = datetime.now().strftime("%Y-%m-%d")
# Out:
# 2026-02-09 16:49:30.967777
# '2026-02-09'

# %%
from datetime import datetime

now1 = datetime.now().strftime("%Y-%m-%d")

# tuple의 형태로 삽입
with conn.cursor() as cursor:
    sql = "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"

    cursor.execute(
        sql, ("user1", "user1@gmail.com", "010-1111-1111", "http://user1.com", now1)
    )

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "select * from users"
    cursor.execute(sql)
    print(cursor.fetchone())
# Out:
# (1, 'user1', 'user1@gmail.com', '010-1111-1111', 'http://user1.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:
    users = (
        ("user2", "user2@gmail.com", "010-1111-1111", "http://user2.com", now1),
        ("user3", "user3@gmail.com", "010-1111-1111", "http://user3.com", now1),
        ("user4", "user4@gmail.com", "010-1111-1111", "http://user4.com", now1),
        ("user5", "user5@gmail.com", "010-1111-1111", "http://user5.com", now1),
    )
    sql = (
        "insert into users(name, email, phone, website, regdate) values(%s,%s,%s,%s,%s)"
    )
    cursor.executemany(sql,users)

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "select * from users"
    cursor.execute(sql)
    for row in cursor.fetchall():
        print(row)
# Out:
# (1, 'user1', 'user1@gmail.com', '010-1111-1111', 'http://user1.com', datetime.date(2026, 2, 9))
# (2, 'user2', 'user2@gmail.com', '010-1111-1111', 'http://user2.com', datetime.date(2026, 2, 9))
# (3, 'user3', 'user3@gmail.com', '010-1111-1111', 'http://user3.com', datetime.date(2026, 2, 9))
# (4, 'user4', 'user4@gmail.com', '010-1111-1111', 'http://user4.com', datetime.date(2026, 2, 9))
# (5, 'user5', 'user5@gmail.com', '010-1111-1111', 'http://user5.com', datetime.date(2026, 2, 9))

# %%
with conn.cursor() as cursor:
    sql = "select * from users where id=%s"
    cursor.execute(sql, 5)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
# Out:
# (5, 'user5', 'user5@gmail.com', '010-1111-1111', 'http://user5.com', datetime.date(2026, 2, 9))

# %% [markdown]
# ### update

# %%
with conn.cursor() as cursor:
    sql = "update users set name=%s where id=%s"
    cursor.execute(sql, ("change2", 2))

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "delete from users where id=%s"
    cursor.execute(sql,5)

conn.commit()

# %%
with conn.cursor() as cursor:
    sql = "select * from users"
    cursor.execute(sql)

    print([row for row in cursor.fetchall()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       2 sql = "select * from users"
#       3 cursor.execute(sql)
# ----> 5 print('\n'.join([row for row in cursor.fetchall()]))
#
# TypeError: sequence item 0: expected str instance, tuple found
