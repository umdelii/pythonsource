# %%
a,b = 10, 20
x = [10, 20, 30]
# print(x[3])

# %%
try:
    # 에러가 발생할 수 있는 구문
    pass
except:
    # 에러 발생 시 할 일
    pass
else:
    # 에러가 발생하지 않는 경우 처리 구문
    pass
finally:
    # 에러 발생여부와 관계없이 처리 구문
    pass

# %%
try:
    a, b = 10, 20
    print(c)
except NameError:
    print('변수명 확인')
# Out:
# 변수명 확인

# %%
try:
    x = [10,20,30]
    print(x[3])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    dict1 = {"name": "hong", "age": 30}
    print(dict1["hobby"])
except Exception as e:
    print(e)
# Out:
# 'hobby'

# %%
try:
    dict1 = {"name": "hong", "age": 30}
    print(dict1["hobby"])
except KeyError as e:
    print(e)
except Exception as e:
    print(e)
# Out:
# 'hobby'

# %%
name = ["hong", "lee", "choi", "kim"]
try:
    z = "lee"
    x = name.index(z)
except:
    print("이름이 없습니다")
else:
    print("이름을 찾았습니다", x)
# Out:
# 이름을 찾았습니다 1

# %%
try:
    print("try")
finally:
    print("good")
# Out:
# try
# good

# %%
# 예외 직접 발생 : java => throw new Exception()
# raise
try:
    a = "333"
    if a == "kim":
        print("ok")
    else:
        raise ValueError
except ValueError:
    print("error")
else:
    print(a)
# Out:
# error
